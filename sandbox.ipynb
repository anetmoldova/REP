# %%
import requests
from bs4 import BeautifulSoup

# %%
url = f"https://www.bezrealitky.cz/vypis/nabidka-pronajem/byt/praha?page"
response = requests.get(url)

response.text
# Out:
# '<!DOCTYPE html><html id="bzrHtml" lang="cs"><head><meta charSet="utf-8" data-next-head=""/><meta name="viewport" content="minimum-scale=1, initial-scale=1, width=device-width, shrink-to-fit=no, user-scalable=no, viewport-fit=cover" data-next-head=""/><link rel="preconnect" href="https://dev.visualwebsiteoptimizer.com" data-next-head=""/><title data-next-head="">Pronájem bytu Praha | Bezrealitky</title><meta name="description" content="Pronájem bytu • Praha • Prohlédněte si byty k pronájmu v naší široké nabídce • Ušetřete peníze za provizi a komunikujte přímo s majitelem." data-next-head=""/><meta name="twitter:title" content="Pronájem bytu Praha | Bezrealitky" data-next-head=""/><meta name="twitter:description" content="Pronájem bytu • Praha • Prohlédněte si byty k pronájmu v naší široké nabídce • Ušetřete peníze za provizi a komunikujte přímo s majitelem." data-next-head=""/><meta name="twitter:url" content="https://www.bezrealitky.cz/vypis/nabidka-pronajem/byt/praha?page=" data-ne
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
main = soup.find('div', class_='box PropertiesMap_propertiesMapScroll__VtwqL bg-white')
main
# Out:
# <div class="box PropertiesMap_propertiesMapScroll__VtwqL bg-white"><div></div><div class="mb-3 d-flex flex-row justify-content-between"><div class="d-lg-none"><p class="text-caption text-red text-ls"><span>Zobrazit mapu</span></p></div></div><h1 class="PropertiesMap_propertiesMapHeading__vE5to mb-3 text-subheadline-lg"><a href="https://www.bezrealitky.cz/vypis/nabidka-pronajem/byt"><span>Byty k pronájmu</span></a> • <a href="https://www.bezrealitky.cz/vypis/nabidka-pronajem/byt/praha">Praha</a></h1><p class="mb-4 form-label">(<span>1 139 nemovitostí</span>)</p><div class="mb-4 d-lg-none"><button class="w-100 btn-sm btn btn-primary" type="button"><span class="Icon_icon__ZG9ss icon Icon_icon--start__bVz3s"><svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M10.854 16.202c.443.442.73.98.865 1.548H21a.75.75 0 01.102 1.493L21 19.25h-9.281a3.25 3.25 0 01-6.325 0H3a.75.75 0 01-.102-1.493L3 17.75h2.393a3.25 3.25 0 015.46-1.548zm-3.535 1.06
# ...

# %%
dlazdice_list = [
    '<div> <h1> Hello </h1> </div>',
    '<div> <h2> Hello </h2> </div>'
]

# %%
iter_list = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
for i in iter_list:
    print(i)
# Out:
# a
# b
# c
# d
# e
# f
# g
# h
# i
# j

# %%
informace = soup.find_all('div', class_="PropertyCard_propertyCardContent__osPAM")
informace
# Out:
# [<div class="PropertyCard_propertyCardContent__osPAM"><h2 class="PropertyCard_propertyCardHeadline___diKI mt-md-0 mt-4 mb-0"><a href="https://www.bezrealitky.cz/nemovitosti-byty-domy/924157-nabidka-pronajem-bytu-bieblova-hlavni-mesto-praha"><span class="PropertyCard_propertyCardLabel__HN3Jo mb-2 text-caption text-grey-dark fw-medium text-uppercase text-truncate" style="-webkit-line-clamp:1"><span>Pronájem bytu</span></span><span class="PropertyCard_propertyCardAddress__hNqyR text-subheadline text-truncate" style="-webkit-line-clamp:1">Bieblova, Praha - Smíchov</span></a></h2><hr class="Divider_divider__h03d0 d-none d-md-block text-grey-light"/><ul class="FeaturesList_featuresList__75Wet featuresList mt-3"><li class="FeaturesList_featuresListItem__RYf_f"><span class="Icon_icon__ZG9ss icon FeaturesList_featuresListItemIcon__klehW"><svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M18.317 2.5a3.184 3.184 0 013.178 3.002l.005.18v12.63
# ...

# %%
title= soup.find_all('h2', class_='PropertyCard_propertyCardHeadline___diKI mt-md-0 mt-4 mb-0')
title
# Out:
# [<h2 class="PropertyCard_propertyCardHeadline___diKI mt-md-0 mt-4 mb-0"><a href="https://www.bezrealitky.cz/nemovitosti-byty-domy/924157-nabidka-pronajem-bytu-bieblova-hlavni-mesto-praha"><span class="PropertyCard_propertyCardLabel__HN3Jo mb-2 text-caption text-grey-dark fw-medium text-uppercase text-truncate" style="-webkit-line-clamp:1"><span>Pronájem bytu</span></span><span class="PropertyCard_propertyCardAddress__hNqyR text-subheadline text-truncate" style="-webkit-line-clamp:1">Bieblova, Praha - Smíchov</span></a></h2>,
# ...

# %%
price = soup.find_all('div', class_="PropertyPrice_propertyPrice__lthza propertyPrice mb-0 mt-3")
price
# Out:
# [<div class="PropertyPrice_propertyPrice__lthza propertyPrice mb-0 mt-3"><span class="PropertyPrice_propertyPriceAmount__WdEE1">20 500 Kč</span><span class="PropertyPrice_propertyPriceAdditional__5jYQ6"> + 3 600 Kč</span><span class="PropertyPrice_propertyPricePerMeter__IfhGa">(<!-- -->526 Kč / m²<!-- -->)</span><span class="w-100"></span></div>,
#  <div class="PropertyPrice_propertyPrice__lthza propertyPrice mb-0 mt-3"><span class="PropertyPrice_propertyPriceAmount__WdEE1">14 500 Kč</span><span class="PropertyPrice_propertyPriceAdditional__5jYQ6"> + 3 859 Kč</span><span class="PropertyPrice_propertyPricePerMeter__IfhGa">(<!-- -->558 Kč / m²<!-- -->)</span><span class="w-100"></span></div>,
# ...

# %%
url = f"https://www.bezrealitky.cz/nemovitosti-byty-domy/861057-nabidka-pronajem-bytu-ujezd-praha"
response = requests.get(url)

response.text
# Out:
# '<!DOCTYPE html><html id="bzrHtml" lang="cs"><head><meta charSet="utf-8" data-next-head=""/><meta name="viewport" content="minimum-scale=1, initial-scale=1, width=device-width, shrink-to-fit=no, user-scalable=no, viewport-fit=cover" data-next-head=""/><link rel="preconnect" href="https://dev.visualwebsiteoptimizer.com" data-next-head=""/><title data-next-head="">Pronájem bytu • 33 m² • Újezd • Praha - Malá Strana • bez RK | Bezrealitky</title><meta name="description" content="Pronájem bytu o rozloze 33 m² na adrese Újezd, Praha - Malá Strana. Vyberte si svůj byt k pronájmu snadno a rychle bez realitky." data-next-head=""/><meta name="twitter:title" content="Pronájem bytu • 33 m² • Újezd • Praha - Malá Strana • bez RK | Bezrealitky" data-next-head=""/><meta name="twitter:description" content="Pronájem bytu o rozloze 33 m² na adrese Újezd, Praha - Malá Strana. Vyberte si svůj byt k pronájmu snadno a rychle bez realitky." data-next-head=""/><meta name="twitter:url" content="https://www.
# ...

# %%
byt=soup.find('main', class_="box mainContent")
byt
# Out:
# <main class="box mainContent"><section class="box Section_section__gjwvr section mb-0"><div class="PropertiesMap_propertiesMap__lqPS7 propertiesMap PropertiesMap_propertiesMap--expanded__qcF6_"><div class="PropertiesMap_propertiesMapHolder__97_19"><div class="PropertiesMap_propertiesMapMap__6H78t"><div class="position-absolute w-100 h-100" style="top:0;bottom:0"></div></div></div><div class="box ContentBox_contentBox__tD7YI contentBox mb-last-0 PropertiesMap_propertiesMapContent__OP8mO ContentBox_contentBox--shadow__FZgFv bg-white"><div class="box PropertiesMap_propertiesMapScroll__VtwqL bg-white"><div></div><div class="mb-3 d-flex flex-row justify-content-between"><div class="d-lg-none"><p class="text-caption text-red text-ls"><span>Zobrazit mapu</span></p></div></div><h1 class="PropertiesMap_propertiesMapHeading__vE5to mb-3 text-subheadline-lg"><a href="https://www.bezrealitky.cz/vypis/nabidka-pronajem/byt"><span>Byty k pronájmu</span></a> • <a href="https://www.bezrealitky.cz/vypi
# ...

# %%
parametry = soup.find('div', class_="ParamsTable_paramsTable__tX8zj paramsTable")
parametry
# Out:
# []

# %%
for card in cards:
    title = card.find('h2', class_='mb-3 mg-lg-10- h2')
    price = card.find('div', class_='col-auto')
    location = card.find('div', class_='span class="d-block text-perex-lg text-grey-dark')
    
    print("Názov:", title.text.strip() if title else "N/A")
    print("Cena:", price.text.strip() if price else "N/A")
    print("Lokalita:", location.text.strip() if location else "N/A")
